# %% [markdown]
# #                              Environmental Kuznets curve

# %% [markdown]
#  ### Statement:
#  The environmental Kuznets curve suggests that economic development initially leads to a deterioration in the environment, but after a certain level of economic growth, a society begins to improve its relationship with the environment and levels of environmental degradation reduces.
#
# From a very simplistic viewpoint, it can suggest that economic growth is good for the environment.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:\\Users\\Dell\\Desktop\\project m.sc\\WDIData.csv')

# %%
countries = data['Country Name'].unique().tolist()
codes = data['Country Code'].unique().tolist()
indicators = data['Indicator Name'].unique().tolist()
print("Countries: %d" % (len(countries))) #Old method of printing
print("Country Codes: {}".format(len(codes)))
print("Indicators: {}".format(len(indicators)))
# Out:
# Countries: 264
# Country Codes: 264
# Indicators: 1443

# %%
print(data.isnull().any().any())
print("\n")
print(data.isnull().sum())
# Out:
# True
#
#
# Country Name           0
# Country Code           0
# Indicator Name         0
# Indicator Code         0
# 1960              343582
#                    ...
# 2016              173888
# 2017              179187
# 2018              189801
# 2019              224012
# 2020              373450
# Length: 65, dtype: int64

# %%
plt.subplots(figsize=(16,6))
first_indicator = 'CO2 emissions \(metric'
x = 'start'
while True:
    if x!= 'stop':
        x = input("Enter Country  ")
        mask1 = data['Indicator Name'].str.contains(first_indicator) 
        mask2 = data['Country Code'].str.contains(x)
# stage is just those indicators matching the USA for country code and CO2 emissions over time.
        c = data[mask1 & mask2]
        c = c.transpose()
        c = c.iloc[4:,]
        df = pd.DataFrame(c)
        df.columns = [x]
        df = df.iloc[:-4]
        plt.plot(df,label =x)
        plt.legend();

    else:
        break
# Out:
# Enter Country  IND
# Enter Country  USA
# Enter Country  CHN
# Enter Country  THA
# Enter Country  BTN
# Enter Country  NOR
# Enter Country  CHE
# Enter Country  IRL
# Enter Country  stop
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-626980648227> in <module>
#      12         c = c.iloc[4:,]
#      13         df = pd.DataFrame(c)
# ---> 14         df.columns = [x]
#      15         df = df.iloc[:-4]
#      16         plt.plot(df,label =x)
#
# ~\Anaconda3\anaconda4\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ...

# %% [markdown]
# This is a graph  Co2 emission in million metric tonnes vs year included 4 developed(Norway =  nor, switerland = CHE, USA, Ireland = IRL) and 4 developing countries(India = IND, China = CHN, Bhutan = BTN, Thailand = THA , BGD = Bangladesh):
#  Developed countries produce more CO2 than developing countries. Now a question in our mind is that it fails kunzet curve as
#  developing should produce more CO2 than developed countries. So, the answer is that in the begining every country is battling to become developed that's why in 1980 developed countries have
#  CO22 emission high but after that 2000 the graph started declining wheras for deveping countries though the CO2 emmission was low than developed but after 2000 it started rising so that country become devloped especially China.
#   lowet Co2 emission is Bhutan

# %%
plt.subplots(figsize=(16,6))
first_indicator = 'GDP per capita \(current'
x = 'start'
while True:
    if x!= 'stop':
        x = input("Enter Country  ")
        mask1 = data['Indicator Name'].str.contains(first_indicator) 
        mask2 = data['Country Code'].str.contains(x)
# stage is just those indicators matching the USA for country code and CO2 emissions over time.
        c = data[mask1 & mask2]
        c = c.iloc[1:,]
        c = c.transpose()
        c = c.iloc[4:,]
        df = pd.DataFrame(c)
        df.columns = [x]
        df = df.iloc[:-1]
        plt.plot(df,label =x)
        plt.legend();

    else:
        break
# Out:
# Enter Country  IND
# Enter Country  USA
# Enter Country  CHN
# Enter Country  NOR
# Enter Country  IRL
# Enter Country  CHE
# Enter Country  THA
# Enter Country  BTN
# Enter Country  stop
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-7143ddcb00da> in <module>
#      13         c = c.iloc[4:,]
#      14         df = pd.DataFrame(c)
# ---> 15         df.columns = [x]
#      16         df = df.iloc[:-1]
#      17         plt.plot(df,label =x)
#
# ~\Anaconda3\anaconda4\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ...

# %%
A clear picture is seen that developed countries has greater GDP than developing highest GDP among all is Norway
 and in developing countries CHINA has highest GDP.

# %%
first_indicator = 'CO2 emissions \(metric'
second_indicator = 'GDP per capita \(current'
# %matplotlib inline
x = 'start'
while True:
    if x!= 'stop':
        x = input("Enter Country  ")
        mask1 = data['Indicator Name'].str.contains(first_indicator) 
        mask2 = data['Country Code'].str.contains(x)
# stage is just those indicators matching the USA for country code and CO2 emissions over time.
        c = data[mask1 & mask2]
        c = c.transpose()
        c = c.iloc[4:,]
        df = pd.DataFrame(c)
        df.columns = [x]
        df = df.iloc[:-4]

        mask11 = data['Indicator Name'].str.contains(second_indicator) 
        mask22 = data['Country Code'].str.contains(x)
# stage is just those indicators matching the USA for country code and CO2 emissions over time.
        c = data[mask11 & mask22]
        c = c.iloc[1:,]
        c = c.transpose()
        c = c.iloc[4:,]
        df1 = pd.DataFrame(c)
        df1 = df1.iloc[:-4]
        
        

#Plotting a subplot 
        fig, axis = plt.subplots()
# Grid lines, Xticks, Xlabel, Ylabel

        axis.yaxis.grid(True)
        axis.set_title('CO2 Emissions vs. GDP (per capita) for USA',fontsize=10)
        axis.set_xlabel("gdp_stage",fontsize=10)   
        axis.set_ylabel("Co2",fontsize=10)
                         # Obtaining CO2 values

        axis.scatter(df1, df)
        plt.show()
    else:
        break
# Out:
# Enter Country  IND
# Enter Country  CHN
# Enter Country  THA
# Enter Country  BTN
# Enter Country  USA
# Enter Country  IRL
# Enter Country  NOR
# Enter Country  CHE
# Enter Country  BGD
# Enter Country  stop
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-3f73ce65f850> in <module>
#      13         c = c.iloc[4:,]
#      14         df = pd.DataFrame(c)
# ---> 15         df.columns = [x]
#      16         df = df.iloc[:-4]
#      17
#
# ~\Anaconda3\anaconda4\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ...

# %% [markdown]
# For all the devloping countries a clear increasing graph is seen i.e we can say that GDP increases when CO2 emission increased and for devoped countries USA and switerzland has decreased the emission of CO2 to some extent but norway and Ireland doesn't decrease much.

# %% [markdown]
# The link between levels of income and environmental degradation is quite weak. It is possible economic growth will be compatible with an improved environment, but it requires a very deliberate set of policies and willingness to produce energy and goods in most environmentally friendly way
